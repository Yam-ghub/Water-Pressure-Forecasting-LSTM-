# %%
#Imports
import numpy as np
import pandas as pd
import tensorflow.keras.backend as k
from sklearn.preprocessing import MinMaxScaler,  RobustScaler
from tensorflow import keras
from tensorflow.keras import Sequential, layers, optimizers, losses, regularizers
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.models import load_model, Sequential
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import Huber

# %%
import numpy as np
import pandas as pd

# Read a specific sheet
df = pd.read_excel(r"C:\Users\William\OneDrive\Documents\Data Cleaning\LARUAN.xlsx",
                   sheet_name='04-VAL04H-PM-1 MIRANDA-PSAN_Pre')

df.head(20)
# Out:
#    Unnamed: 0                            Unnamed: 1           Unnamed: 2  \
# 0         NaN                                   NaN                  NaN
# 1         NaN                                   NaN                  NaN
# 2         NaN                                   NaN                  NaN
# 3         NaN                                   NaN                  NaN
# 4         NaN                                   NaN                  NaN
# 5         PMP  04-VAL04H-PM-1 MIRANDA-PSAN_Pressure             DATETIME
# 6         NaN                                   NaN  2022-01-01 00:00:00
# 7         NaN                                   NaN  2022-01-01 00:15:00
# 8         NaN                                   NaN  2022-01-01 00:30:00
# 9         NaN                                   NaN  2022-01-01 00:45:00
# 10        NaN                                   NaN  2022-01-01 01:00:00
# 11        NaN                                   NaN  2022-01-01 01:15:00
# 12        NaN                                   NaN  2022-01-01 01:30:00
# 13        NaN                                   NaN  2022-01-01 01:45:00
# 14        NaN                                   NaN  2022-01-01 02:00:00
# 15        NaN                                   NaN  2022-01-01 02:15:00
# 16        NaN                                   NaN  2022-01-01 02:30:00
# 17        NaN                                   NaN  2022-01-01 02:45:00
# 18        NaN                                   NaN  2022-01-01 03:00:00
# 19        NaN                                   NaN  2022-01-01 03:15:00
#
#                                     Unnamed: 3
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          PSI
# 6   [-11057] Not Enough Values For Calculation
# 7   [-11057] Not Enough Values For Calculation
# 8   [-11057] Not Enough Values For Calculation
# 9   [-11057] Not Enough Values For Calculation
# 10  [-11057] Not Enough Values For Calculation
# 11  [-11057] Not Enough Values For Calculation
# 12  [-11057] Not Enough Values For Calculation
# 13  [-11057] Not Enough Values For Calculation
# 14  [-11057] Not Enough Values For Calculation
# 15  [-11057] Not Enough Values For Calculation
# 16  [-11057] Not Enough Values For Calculation
# 17  [-11057] Not Enough Values For Calculation
# 18  [-11057] Not Enough Values For Calculation
# 19  [-11057] Not Enough Values For Calculation

# %%
# Don't use this unless you're gonna change your prv dataset.
# to clean

df.drop(['Unnamed: 1', 'Unnamed: 0'], axis=1, inplace=True)
df.to_csv('semicleaned3.csv', index=False)
df.head(100)
# Out:
#              Unnamed: 2                                  Unnamed: 3
# 0                   NaN                                         NaN
# 1                   NaN                                         NaN
# 2                   NaN                                         NaN
# 3                   NaN                                         NaN
# 4                   NaN                                         NaN
# ..                  ...                                         ...
# 95  2022-01-01 22:15:00  [-11057] Not Enough Values For Calculation
# 96  2022-01-01 22:30:00  [-11057] Not Enough Values For Calculation
# 97  2022-01-01 22:45:00  [-11057] Not Enough Values For Calculation
# 98  2022-01-01 23:00:00  [-11057] Not Enough Values For Calculation
# 99  2022-01-01 23:15:00  [-11057] Not Enough Values For Calculation
#
# [100 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
#Cleaning changing Not enough values to NaN
df3 = pd.read_csv("semicleaned3.csv", skiprows=6)
df3.columns = ['DATETIME', 'PSI']
df3.replace('[-11057] Not Enough Values For Calculation', np.nan, inplace=True)
#changing data types

df3['PSI'] = pd.to_numeric(df3['PSI'], errors='coerce')
df3['DATETIME'] = pd.to_datetime(df3['DATETIME'], errors='coerce')
df3.dtypes
df3
# Out:
#                   DATETIME   PSI
# 0      2022-01-01 00:00:00   NaN
# 1      2022-01-01 00:15:00   NaN
# 2      2022-01-01 00:30:00   NaN
# 3      2022-01-01 00:45:00   NaN
# 4      2022-01-01 01:00:00   NaN
# ...                    ...   ...
# 101659 2024-11-24 22:45:00  7.81
# 101660 2024-11-24 23:00:00  9.23
# 101661 2024-11-24 23:15:00  9.94
# 101662 2024-11-24 23:30:00  8.52
# 101663 2024-11-24 23:45:00  9.23
#
# [101664 rows x 2 columns]

# %%
df_new = df3.copy()  # Creates a separate copy
df_new.index = df_new['DATETIME']
df_new.drop('DATETIME', axis=1, inplace=True)

df_new
# Out:
#                       PSI
# DATETIME
# 2022-01-01 00:00:00   NaN
# 2022-01-01 00:15:00   NaN
# 2022-01-01 00:30:00   NaN
# 2022-01-01 00:45:00   NaN
# 2022-01-01 01:00:00   NaN
# ...                   ...
# 2024-11-24 22:45:00  7.81
# 2024-11-24 23:00:00  9.23
# 2024-11-24 23:15:00  9.94
# 2024-11-24 23:30:00  8.52
# 2024-11-24 23:45:00  9.23
#
# [101664 rows x 1 columns]

# %%
df_new.loc[df_new['PSI'] > 30, 'PSI'] = np.nan
df_new['PSI'] = df_new['PSI'].interpolate(method='time')
df_new['PSI'] = df_new['PSI'].rolling(window=5, center=True, min_periods=1).median()

# %%
df_new.isnull().sum()
# Out:
# PSI    7103
# dtype: int64

# %%
df_new.fillna(0.01, inplace=True)

# %%
df_new[df_new < 0] = 0.01

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a box plot
sns.boxplot(data=df_new, x='PSI')
# Set the figure size
plt.figure(figsize=(10, 6))
# Set the style of the plot
sns.set(style="whitegrid")

# Show the plot
plt.show()

# %%
df_new
# Out:
#                       PSI
# DATETIME
# 2022-01-01 00:00:00  0.01
# 2022-01-01 00:15:00  0.01
# 2022-01-01 00:30:00  0.01
# 2022-01-01 00:45:00  0.01
# 2022-01-01 01:00:00  0.01
# ...                   ...
# 2024-11-24 22:45:00  8.52
# 2024-11-24 23:00:00  8.52
# 2024-11-24 23:15:00  9.23
# 2024-11-24 23:30:00  9.23
# 2024-11-24 23:45:00  9.23
#
# [101664 rows x 1 columns]

# %%
#visualizing my dataframe
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))

# Plot using numerical indices on the x-axis
plt.plot(df_new.index, df_new['PSI'], label='PSI')
# Formatting

# %%
df_new['PSI']
# Out:
# DATETIME
# 2022-01-01 00:00:00    0.01
# 2022-01-01 00:15:00    0.01
# 2022-01-01 00:30:00    0.01
# 2022-01-01 00:45:00    0.01
# 2022-01-01 01:00:00    0.01
#                        ...
# 2024-11-24 22:45:00    8.52
# 2024-11-24 23:00:00    8.52
# 2024-11-24 23:15:00    9.23
# 2024-11-24 23:30:00    9.23
# 2024-11-24 23:45:00    9.23
# Name: PSI, Length: 101664, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
len(df_new)
# Out:
# 101664

# %%
scaler.fit(df_new)
# Out:
# MinMaxScaler()

# %%
scaled_data = scaler.transform(df_new)

# %%
def create_input_output(data, input_length, output_length):
    X, y = [], []
    for i in range(len(data) - input_length - output_length + 1):
        # Input: Sequence of past values
        X.append(data[i:i + input_length])
        # Output: Sequence of future values
        y.append(data[i + input_length:i + input_length + output_length])
    return np.array(X), np.array(y)

INPUT_LENGTH = 30  # Number of past time steps (input sequence length)
OUTPUT_LENGTH = 1  # Number of future time steps (output sequence length)

# Create input-output sequences
X, y = create_input_output(scaled_data, INPUT_LENGTH, OUTPUT_LENGTH)

# Reshape for LSTM input (samples, time steps, features)
X = X.reshape(X.shape[0], X.shape[1], 1)  # (samples, time steps, features)

# Train-Test Split (70% training, 30% testing)
train_size = int(len(X) * 0.7)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Print shapes for verification
print("X_train shape:", X_train.shape)  # (samples, input_length, features)
print("X_test shape:", X_test.shape)    # (samples, input_length, features)
print("y_train shape:", y_train.shape)  # (samples, output_length)
print("y_test shape:", y_test.shape)    # (samples, output_length)
# Out:
# X_train shape: (71143, 30, 1)
# X_test shape: (30491, 30, 1)
# y_train shape: (71143, 1, 1)
# y_test shape: (30491, 1, 1)

# %%
print(f"Length of scaled_data: {len(scaled_data)}")
print(f"Required length: {INPUT_LENGTH + OUTPUT_LENGTH}")
# Out:
# Length of scaled_data: 101664
# Required length: 31

# %%
#building model
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    BatchNormalization(),
    Dropout(0.2),
    LSTM(32, return_sequences=False),
    BatchNormalization(), 
    Dropout(0.2),
    Dense(16, activation='relu', kernel_regularizer=l2(0.0001)),
    BatchNormalization(), 
    Dropout(0.3),
    Dense(1)
])
# Out:
# c:\Users\William\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,305 (118.38 KB)
#  Trainable params: 30,081 (117.50 KB)
#  Non-trainable params: 224 (896.00 B)

# %%
# Compile model with Huber loss and Adam optimizer
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss=Huber(delta=1),
    metrics=['mae']
)

# Reduce LR if validation loss stops improving
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-6, verbose=1)

# Model checkpoint to save the best model
model_checkpoint = ModelCheckpoint(
    filepath="Predict15steps.keras",
    monitor="val_loss",
    save_best_only=True,
    mode="min",
    verbose=1
)

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=40,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[ reduce_lr, model_checkpoint],
    verbose=1
)
# Out:
# Epoch 1/40
# 2220/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4606 - mae: 0.8084
# Epoch 1: val_loss improved from inf to 0.00568, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 27s 11ms/step - loss: 0.4603 - mae: 0.8080 - val_loss: 0.0057 - val_mae: 0.0686 - learning_rate: 1.0000e-04
# Epoch 2/40
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1439 - mae: 0.3795
# Epoch 2: val_loss improved from 0.00568 to 0.00526, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - loss: 0.1439 - mae: 0.3794 - val_loss: 0.0053 - val_mae: 0.0673 - learning_rate: 1.0000e-04
# Epoch 3/40
# 2219/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0654 - mae: 0.2317
# Epoch 3: val_loss improved from 0.00526 to 0.00300, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - loss: 0.0653 - mae: 0.2316 - val_loss: 0.0030 - val_mae: 0.0316 - learning_rate: 1.0000e-04
# Epoch 4/40
# 2222/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0273 - mae: 0.1492
# Epoch 4: val_loss improved from 0.00300 to 0.00281, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - loss: 0.0273 - mae: 0.1492 - val_loss: 0.0028 - val_mae: 0.0284 - learning_rate: 1.0000e-04
# Epoch 5/40
# 2220/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0110 - mae: 0.0965
# Epoch 5: val_loss improved from 0.00281 to 0.00244, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 26s 12ms/step - loss: 0.0110 - mae: 0.0965 - val_loss: 0.0024 - val_mae: 0.0230 - learning_rate: 1.0000e-04
# Epoch 6/40
# 2221/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0063 - mae: 0.0698
# Epoch 6: val_loss improved from 0.00244 to 0.00203, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - loss: 0.0063 - mae: 0.0698 - val_loss: 0.0020 - val_mae: 0.0218 - learning_rate: 1.0000e-04
# Epoch 7/40
# 2220/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0047 - mae: 0.0594
# Epoch 7: val_loss improved from 0.00203 to 0.00143, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 26s 12ms/step - loss: 0.0047 - mae: 0.0594 - val_loss: 0.0014 - val_mae: 0.0195 - learning_rate: 1.0000e-04
# Epoch 8/40
# 2221/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - mae: 0.0551
# Epoch 8: val_loss improved from 0.00143 to 0.00092, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - loss: 0.0037 - mae: 0.0551 - val_loss: 9.2318e-04 - val_mae: 0.0165 - learning_rate: 1.0000e-04
# Epoch 9/40
# 2223/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032 - mae: 0.0539
# Epoch 9: val_loss improved from 0.00092 to 0.00080, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - loss: 0.0032 - mae: 0.0539 - val_loss: 8.0275e-04 - val_mae: 0.0234 - learning_rate: 1.0000e-04
# Epoch 10/40
# 2221/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029 - mae: 0.0527
# Epoch 10: val_loss improved from 0.00080 to 0.00053, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 26s 12ms/step - loss: 0.0029 - mae: 0.0527 - val_loss: 5.2889e-04 - val_mae: 0.0184 - learning_rate: 1.0000e-04
# Epoch 11/40
# 2221/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0028 - mae: 0.0545
# Epoch 11: val_loss did not improve from 0.00053
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 29s 13ms/step - loss: 0.0028 - mae: 0.0545 - val_loss: 5.4944e-04 - val_mae: 0.0226 - learning_rate: 1.0000e-04
# Epoch 12/40
# 2219/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0025 - mae: 0.0516
# Epoch 12: val_loss improved from 0.00053 to 0.00035, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 30s 13ms/step - loss: 0.0025 - mae: 0.0516 - val_loss: 3.4974e-04 - val_mae: 0.0151 - learning_rate: 1.0000e-04
# Epoch 13/40
# 2219/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0025 - mae: 0.0516
# Epoch 13: val_loss did not improve from 0.00035
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 27s 12ms/step - loss: 0.0025 - mae: 0.0516 - val_loss: 4.0304e-04 - val_mae: 0.0192 - learning_rate: 1.0000e-04
# Epoch 14/40
# 2220/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0507
# Epoch 14: val_loss did not improve from 0.00035
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - loss: 0.0023 - mae: 0.0507 - val_loss: 3.9408e-04 - val_mae: 0.0204 - learning_rate: 1.0000e-04
# Epoch 15/40
# 2221/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023 - mae: 0.0505
# Epoch 15: val_loss did not improve from 0.00035
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 24s 11ms/step - loss: 0.0023 - mae: 0.0505 - val_loss: 3.6508e-04 - val_mae: 0.0194 - learning_rate: 1.0000e-04
# Epoch 16/40
# 2221/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022 - mae: 0.0494
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 16: val_loss improved from 0.00035 to 0.00034, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 25s 11ms/step - loss: 0.0022 - mae: 0.0494 - val_loss: 3.3609e-04 - val_mae: 0.0185 - learning_rate: 1.0000e-04
# Epoch 17/40
# 2223/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022 - mae: 0.0493
# Epoch 17: val_loss improved from 0.00034 to 0.00029, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 26s 12ms/step - loss: 0.0022 - mae: 0.0493 - val_loss: 2.9239e-04 - val_mae: 0.0162 - learning_rate: 5.0000e-05
# Epoch 18/40
# 2222/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0022 - mae: 0.0495
# Epoch 18: val_loss improved from 0.00029 to 0.00027, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 28s 12ms/step - loss: 0.0022 - mae: 0.0495 - val_loss: 2.6592e-04 - val_mae: 0.0144 - learning_rate: 5.0000e-05
# Epoch 19/40
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0022 - mae: 0.0496
# Epoch 19: val_loss improved from 0.00027 to 0.00026, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 52s 23ms/step - loss: 0.0022 - mae: 0.0496 - val_loss: 2.5825e-04 - val_mae: 0.0133 - learning_rate: 5.0000e-05
# Epoch 20/40
# 2223/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0022 - mae: 0.0500
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 20: val_loss did not improve from 0.00026
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 98s 44ms/step - loss: 0.0022 - mae: 0.0500 - val_loss: 2.6627e-04 - val_mae: 0.0147 - learning_rate: 5.0000e-05
# Epoch 21/40
# 2223/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0021 - mae: 0.0489
# Epoch 21: val_loss did not improve from 0.00026
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 160s 52ms/step - loss: 0.0021 - mae: 0.0489 - val_loss: 2.7825e-04 - val_mae: 0.0155 - learning_rate: 2.5000e-05
# Epoch 22/40
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0022 - mae: 0.0491
# Epoch 22: val_loss did not improve from 0.00026
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 111s 50ms/step - loss: 0.0022 - mae: 0.0491 - val_loss: 2.7336e-04 - val_mae: 0.0153 - learning_rate: 2.5000e-05
# Epoch 23/40
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0021 - mae: 0.0490
# Epoch 23: val_loss did not improve from 0.00026
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 99s 44ms/step - loss: 0.0021 - mae: 0.0490 - val_loss: 2.5895e-04 - val_mae: 0.0143 - learning_rate: 2.5000e-05
# Epoch 24/40
# 2220/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0021 - mae: 0.0488
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 24: val_loss did not improve from 0.00026
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 62s 28ms/step - loss: 0.0021 - mae: 0.0488 - val_loss: 2.8165e-04 - val_mae: 0.0158 - learning_rate: 2.5000e-05
# Epoch 25/40
# 2223/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0021 - mae: 0.0481
# Epoch 25: val_loss did not improve from 0.00026
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 134s 51ms/step - loss: 0.0021 - mae: 0.0481 - val_loss: 2.6978e-04 - val_mae: 0.0151 - learning_rate: 1.2500e-05
# Epoch 26/40
# 2223/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0021 - mae: 0.0478
# Epoch 26: val_loss did not improve from 0.00026
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 94s 42ms/step - loss: 0.0021 - mae: 0.0478 - val_loss: 3.1061e-04 - val_mae: 0.0177 - learning_rate: 1.2500e-05
# Epoch 27/40
# 2223/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0021 - mae: 0.0481
# Epoch 27: val_loss did not improve from 0.00026
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 93s 42ms/step - loss: 0.0021 - mae: 0.0481 - val_loss: 2.7394e-04 - val_mae: 0.0154 - learning_rate: 1.2500e-05
# Epoch 28/40
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0021 - mae: 0.0488
# Epoch 28: val_loss improved from 0.00026 to 0.00025, saving model to Predict15steps.keras
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 84s 38ms/step - loss: 0.0021 - mae: 0.0488 - val_loss: 2.4878e-04 - val_mae: 0.0133 - learning_rate: 1.2500e-05
# Epoch 29/40
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0021 - mae: 0.0481
# Epoch 29: val_loss did not improve from 0.00025
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 83s 37ms/step - loss: 0.0021 - mae: 0.0481 - val_loss: 3.3521e-04 - val_mae: 0.0191 - learning_rate: 1.2500e-05
# Epoch 30/40
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0022 - mae: 0.0490
# Epoch 30: val_loss did not improve from 0.00025
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 91s 41ms/step - loss: 0.0022 - mae: 0.0490 - val_loss: 3.2321e-04 - val_mae: 0.0185 - learning_rate: 1.2500e-05
# Epoch 31/40
# 2223/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0021 - mae: 0.0483
# Epoch 31: val_loss did not improve from 0.00025
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 87s 39ms/step - loss: 0.0021 - mae: 0.0483 - val_loss: 3.6722e-04 - val_mae: 0.0206 - learning_rate: 1.2500e-05
# Epoch 32/40
# 2222/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0021 - mae: 0.0490
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 32: val_loss did not improve from 0.00025
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 86s 39ms/step - loss: 0.0021 - mae: 0.0490 - val_loss: 2.5835e-04 - val_mae: 0.0144 - learning_rate: 1.2500e-05
# Epoch 33/40
# 2222/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0021 - mae: 0.0484
# Epoch 33: val_loss did not improve from 0.00025
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 89s 40ms/step - loss: 0.0021 - mae: 0.0484 - val_loss: 2.7168e-04 - val_mae: 0.0154 - learning_rate: 6.2500e-06
# Epoch 34/40
# 2222/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0021 - mae: 0.0482
# Epoch 34: val_loss did not improve from 0.00025
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 97s 43ms/step - loss: 0.0021 - mae: 0.0482 - val_loss: 2.5352e-04 - val_mae: 0.0140 - learning_rate: 6.2500e-06
# Epoch 35/40
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0021 - mae: 0.0486
# Epoch 35: val_loss did not improve from 0.00025
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 94s 42ms/step - loss: 0.0021 - mae: 0.0486 - val_loss: 2.5915e-04 - val_mae: 0.0144 - learning_rate: 6.2500e-06
# Epoch 36/40
# 2222/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0021 - mae: 0.0487
# Epoch 36: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#
# Epoch 36: val_loss did not improve from 0.00025
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 98s 44ms/step - loss: 0.0021 - mae: 0.0487 - val_loss: 3.0584e-04 - val_mae: 0.0176 - learning_rate: 6.2500e-06
# Epoch 37/40
# 2222/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0021 - mae: 0.0483
# Epoch 37: val_loss did not improve from 0.00025
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 85s 38ms/step - loss: 0.0021 - mae: 0.0483 - val_loss: 2.8124e-04 - val_mae: 0.0161 - learning_rate: 3.1250e-06
# Epoch 38/40
# 2222/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0021 - mae: 0.0479
# Epoch 38: val_loss did not improve from 0.00025
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 109s 49ms/step - loss: 0.0021 - mae: 0.0479 - val_loss: 2.5846e-04 - val_mae: 0.0145 - learning_rate: 3.1250e-06
# Epoch 39/40
# 2222/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0021 - mae: 0.0480
# Epoch 39: val_loss did not improve from 0.00025
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 85s 38ms/step - loss: 0.0021 - mae: 0.0480 - val_loss: 2.8100e-04 - val_mae: 0.0161 - learning_rate: 3.1250e-06
# Epoch 40/40
# 2223/2224 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0021 - mae: 0.0484
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
#
# Epoch 40: val_loss did not improve from 0.00025
# 2224/2224 ━━━━━━━━━━━━━━━━━━━━ 89s 40ms/step - loss: 0.0021 - mae: 0.0484 - val_loss: 2.4979e-04 - val_mae: 0.0137 - learning_rate: 3.1250e-06

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)
loss_per_epoch = model.history.history['val_loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
from tensorflow.keras.models import load_model

# Load the saved model
model = load_model("Predict15steps.keras")

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 30, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 30, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 90,469 (353.40 KB)
#  Trainable params: 30,081 (117.50 KB)
#  Non-trainable params: 224 (896.00 B)
#  Optimizer params: 60,164 (235.02 KB)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# Generate predictions for the test set
y_pred = model.predict(X_test)
# Out:
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step

# %%
# Reshape y_pred to match y_test
epsilon = 0.1  # Small constant to avoid division by zero
#y_pred = np.squeeze(y_pred)  # Remove the last dimension if it exists
# Validate the shapes
print("y_test shape:", y_test.shape)
print("y_pred shape:", y_pred.shape)
# Out:
# y_test shape: (30491, 1, 1)
# y_pred shape: (30491, 1)

# %%
# Reshape y_test and y_pred to match each other
y_test = np.squeeze(y_test)  # Remove the last dimension from y_test
y_pred = np.squeeze(y_pred)  # Remove the last dimension from y_pred

# Validate the shapes
print("y_test shape:", y_test.shape)
print("y_pred shape:", y_pred.shape)

# Calculate SMAPE
# SMAPE function
mape = np.mean(np.abs((y_test - y_pred) / (y_test + epsilon))) * 100
print(f'MAPE: {mape:.4f}')

# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
print(f'MAE: {mae:.4f}')

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'RMSE: {rmse:.4f}')
# Out:
# y_test shape: (30491,)
# y_pred shape: (30491,)
# MAPE: 2.8970
# MAE: 0.0133
# RMSE: 0.0217

# %%
import matplotlib.pyplot as plt

# Flatten y_train, y_test, and y_pred if necessary
y_train_flat = y_train.flatten()
y_test_flat = y_test.flatten()
y_pred_flat = y_pred.flatten()

# Calculate RMSE and MAPE
rmse = np.sqrt(mean_squared_error(y_test_flat, y_pred_flat))
mape_value = 100 * np.mean(np.abs((y_test_flat - y_pred_flat) / y_test_flat))

# Plot the comparison
plt.figure(figsize=(18, 8))

# Plot actual training data
plt.plot(range(len(y_train_flat)), y_train_flat, label="Actual Training Data", color="blue", linewidth=2)  # Blue

# Plot actual test data
plt.plot(range(len(y_train_flat), len(y_train_flat) + len(y_test_flat)), 
         y_test_flat, label="Actual Test Data", color="red", linewidth=2)  # Orange

# Plot predicted data
plt.plot(range(len(y_train_flat), len(y_train_flat) + len(y_pred_flat)), 
         y_pred_flat, label=f"Predicted Data (RMSE: {rmse:.4f}, MAPE: {mape:.2f}')", color="orange", linewidth=2)  # Green

# Formatting
plt.title("Comparison of Training Data, Test Data, and Predicted Data", fontsize=16)
plt.xlabel("Time Steps", fontsize=14)
plt.ylabel("Pressure (PSI)", fontsize=14)
plt.legend(fontsize=12, loc="upper left")
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\William\AppData\Local\Temp\ipykernel_11376\2992303162.py:10: RuntimeWarning: divide by zero encountered in divide
#   mape_value = 100 * np.mean(np.abs((y_test_flat - y_pred_flat) / y_test_flat))

# %% [markdown]
# Testing

# %%
from tensorflow.keras.models import load_model
import numpy as np

model = load_model('Predict15steps.keras')  # Load your trained model

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Example synthetic data (replace with your data)
synthetic_data = pd.read_csv('TestingData.csv')  

# Apply your preprocessing pipeline # Time interpolation
synthetic_data.fillna(0.1, inplace=True)                  # Replace NaN with 0
synthetic_data = synthetic_data.rolling(window=11, min_periods=1).median()  # Rolling median

# Min-Max Scaling (use the same scaler as training or fit a new one)
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(synthetic_data)  # Or use scaler from training

# %%
synthetic_data
# Out:
#        8.5058
# 0    10.46030
# 1     9.52460
# 2    10.46030
# 3     9.56615
# 4    10.46030
# ..        ...
# 189  10.46030
# 190  10.03400
# 191  10.46030
# 192  10.15870
# 193  10.46030
#
# [194 rows x 1 columns]

# %%
y_pred = model.predict(X_test)  # Predict 15 steps ahead
# Out:
# 953/953 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step

# %%
y_test = np.squeeze(y_test)  # Remove the last dimension from y_test
y_pred = np.squeeze(y_pred)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Ensure y_test and y_pred are reshaped to 2D or 1D arrays
y_test = np.squeeze(y_test)  # Remove extra dimensions if any
y_pred = np.squeeze(y_pred)

# Calculate MAE and RMSE
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# Calculate SMAPE with a threshold
threshold = 0.1  # Define a threshold for small values
valid_indices = (np.abs(y_test) > threshold) | (np.abs(y_pred) > threshold)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# --- STEP 5: Print Actual vs Predicted Values ---
print("\n--- Actual vs Predicted Values ---")
for i in range(len(y_test)):
    print(f"\nSample {i+1}:")
    print("Actual    :", np.round(y_test[i], 2))  # Rounded for readability
    print("Predicted :", np.round(y_pred[i], 2))

# --- STEP 6: Evaluate Forecast Accuracy ---
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# Calculate MAPE (handle division by zero by adding a small constant)
epsilon = 0.1  # Small constant to avoid division by zero
mape = np.mean(np.abs((y_test - y_pred) / (y_test + epsilon))) * 100

print(f"\n--- Evaluation Metrics ---\nMAE: {mae:.4f}\nRMSE: {rmse:.4f}\nMAPE: {mape:.2f}%")
# Out:
# --- Actual vs Predicted Values ---
#
# Sample 1:
# Actual    : 0.4
# Predicted : 0.34
#
# Sample 2:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 3:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 4:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 5:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 6:
# Actual    : 0.38
# Predicted : 0.4
#
# Sample 7:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 8:
# Actual    : 0.4
# Predicted : 0.38
#
# Sample 9:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 10:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 11:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 12:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 13:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 14:
# Actual    : 0.48
# Predicted : 0.43
#
# Sample 15:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 16:
# Actual    : 0.45
# Predicted : 0.48
#
# Sample 17:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 18:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 19:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 20:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 21:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 22:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 23:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 24:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 25:
# Actual    : 0.48
# Predicted : 0.5
#
# Sample 26:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 27:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 28:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 29:
# Actual    : 0.45
# Predicted : 0.48
#
# Sample 30:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 31:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 32:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 33:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 34:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 35:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 36:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 37:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 38:
# Actual    : 0.45
# Predicted : 0.41
#
# Sample 39:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 40:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 41:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 42:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 43:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 44:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 45:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 46:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 47:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 48:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 49:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 50:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 51:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 52:
# Actual    : 0.38
# Predicted : 0.45
#
# Sample 53:
# Actual    : 0.38
# Predicted : 0.37
#
# Sample 54:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 55:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 56:
# Actual    : 0.43
# Predicted : 0.39
#
# Sample 57:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 58:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 59:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 60:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 61:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 62:
# Actual    : 0.48
# Predicted : 0.46
#
# Sample 63:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 64:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 65:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 66:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 67:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 68:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 69:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 70:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 71:
# Actual    : 0.48
# Predicted : 0.5
#
# Sample 72:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 73:
# Actual    : 0.5
# Predicted : 0.47
#
# Sample 74:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 75:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 76:
# Actual    : 0.57
# Predicted : 0.52
#
# Sample 77:
# Actual    : 0.62
# Predicted : 0.58
#
# Sample 78:
# Actual    : 0.62
# Predicted : 0.63
#
# Sample 79:
# Actual    : 0.6
# Predicted : 0.62
#
# Sample 80:
# Actual    : 0.6
# Predicted : 0.59
#
# Sample 81:
# Actual    : 0.52
# Predicted : 0.59
#
# Sample 82:
# Actual    : 0.48
# Predicted : 0.51
#
# Sample 83:
# Actual    : 0.43
# Predicted : 0.46
#
# Sample 84:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 85:
# Actual    : 0.38
# Predicted : 0.4
#
# Sample 86:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 87:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 88:
# Actual    : 0.36
# Predicted : 0.39
#
# Sample 89:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 90:
# Actual    : 0.31
# Predicted : 0.36
#
# Sample 91:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 92:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 93:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 94:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 95:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 96:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 97:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 98:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 99:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 100:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 101:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 102:
# Actual    : 0.33
# Predicted : 0.31
#
# Sample 103:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 104:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 105:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 106:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 107:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 108:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 109:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 110:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 111:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 112:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 113:
# Actual    : 0.33
# Predicted : 0.36
#
# Sample 114:
# Actual    : 0.33
# Predicted : 0.33
#
# Sample 115:
# Actual    : 0.38
# Predicted : 0.34
#
# Sample 116:
# Actual    : 0.38
# Predicted : 0.4
#
# Sample 117:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 118:
# Actual    : 0.45
# Predicted : 0.39
#
# Sample 119:
# Actual    : 0.45
# Predicted : 0.47
#
# Sample 120:
# Actual    : 0.43
# Predicted : 0.46
#
# Sample 121:
# Actual    : 0.38
# Predicted : 0.42
#
# Sample 122:
# Actual    : 0.43
# Predicted : 0.37
#
# Sample 123:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 124:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 125:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 126:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 127:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 128:
# Actual    : 0.38
# Predicted : 0.45
#
# Sample 129:
# Actual    : 0.38
# Predicted : 0.37
#
# Sample 130:
# Actual    : 0.4
# Predicted : 0.38
#
# Sample 131:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 132:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 133:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 134:
# Actual    : 0.45
# Predicted : 0.41
#
# Sample 135:
# Actual    : 0.43
# Predicted : 0.46
#
# Sample 136:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 137:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 138:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 139:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 140:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 141:
# Actual    : 0.5
# Predicted : 0.47
#
# Sample 142:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 143:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 144:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 145:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 146:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 147:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 148:
# Actual    : 0.43
# Predicted : 0.52
#
# Sample 149:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 150:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 151:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 152:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 153:
# Actual    : 0.48
# Predicted : 0.44
#
# Sample 154:
# Actual    : 0.48
# Predicted : 0.49
#
# Sample 155:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 156:
# Actual    : 0.5
# Predicted : 0.47
#
# Sample 157:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 158:
# Actual    : 0.48
# Predicted : 0.5
#
# Sample 159:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 160:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 161:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 162:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 163:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 164:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 165:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 166:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 167:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 168:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 169:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 170:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 171:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 172:
# Actual    : 0.64
# Predicted : 0.52
#
# Sample 173:
# Actual    : 0.64
# Predicted : 0.66
#
# Sample 174:
# Actual    : 0.67
# Predicted : 0.65
#
# Sample 175:
# Actual    : 0.64
# Predicted : 0.67
#
# Sample 176:
# Actual    : 0.64
# Predicted : 0.64
#
# Sample 177:
# Actual    : 0.67
# Predicted : 0.64
#
# Sample 178:
# Actual    : 0.67
# Predicted : 0.67
#
# Sample 179:
# Actual    : 0.64
# Predicted : 0.67
#
# Sample 180:
# Actual    : 0.6
# Predicted : 0.63
#
# Sample 181:
# Actual    : 0.55
# Predicted : 0.58
#
# Sample 182:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 183:
# Actual    : 0.48
# Predicted : 0.51
#
# Sample 184:
# Actual    : 0.43
# Predicted : 0.46
#
# Sample 185:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 186:
# Actual    : 0.31
# Predicted : 0.4
#
# Sample 187:
# Actual    : 0.31
# Predicted : 0.3
#
# Sample 188:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 189:
# Actual    : 0.31
# Predicted : 0.33
#
# Sample 190:
# Actual    : 0.31
# Predicted : 0.33
#
# Sample 191:
# Actual    : 0.31
# Predicted : 0.33
#
# Sample 192:
# Actual    : 0.29
# Predicted : 0.32
#
# Sample 193:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 194:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 195:
# Actual    : 0.29
# Predicted : 0.3
#
# Sample 196:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 197:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 198:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 199:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 200:
# Actual    : 0.31
# Predicted : 0.29
#
# Sample 201:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 202:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 203:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 204:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 205:
# Actual    : 0.33
# Predicted : 0.31
#
# Sample 206:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 207:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 208:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 209:
# Actual    : 0.38
# Predicted : 0.36
#
# Sample 210:
# Actual    : 0.4
# Predicted : 0.39
#
# Sample 211:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 212:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 213:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 214:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 215:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 216:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 217:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 218:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 219:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 220:
# Actual    : 0.4
# Predicted : 0.43
#
# Sample 221:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 222:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 223:
# Actual    : 0.45
# Predicted : 0.41
#
# Sample 224:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 225:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 226:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 227:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 228:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 229:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 230:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 231:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 232:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 233:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 234:
# Actual    : 0.52
# Predicted : 0.46
#
# Sample 235:
# Actual    : 0.45
# Predicted : 0.54
#
# Sample 236:
# Actual    : 0.5
# Predicted : 0.45
#
# Sample 237:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 238:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 239:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 240:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 241:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 242:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 243:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 244:
# Actual    : 0.43
# Predicted : 0.49
#
# Sample 245:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 246:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 247:
# Actual    : 0.4
# Predicted : 0.43
#
# Sample 248:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 249:
# Actual    : 0.45
# Predicted : 0.44
#
# Sample 250:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 251:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 252:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 253:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 254:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 255:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 256:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 257:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 258:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 259:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 260:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 261:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 262:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 263:
# Actual    : 0.48
# Predicted : 0.5
#
# Sample 264:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 265:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 266:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 267:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 268:
# Actual    : 0.57
# Predicted : 0.5
#
# Sample 269:
# Actual    : 0.57
# Predicted : 0.58
#
# Sample 270:
# Actual    : 0.57
# Predicted : 0.58
#
# Sample 271:
# Actual    : 0.55
# Predicted : 0.57
#
# Sample 272:
# Actual    : 0.52
# Predicted : 0.54
#
# Sample 273:
# Actual    : 0.48
# Predicted : 0.51
#
# Sample 274:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 275:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 276:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 277:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 278:
# Actual    : 0.36
# Predicted : 0.43
#
# Sample 279:
# Actual    : 0.36
# Predicted : 0.35
#
# Sample 280:
# Actual    : 0.33
# Predicted : 0.36
#
# Sample 281:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 282:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 283:
# Actual    : 0.33
# Predicted : 0.37
#
# Sample 284:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 285:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 286:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 287:
# Actual    : 0.4
# Predicted : 0.37
#
# Sample 288:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 289:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 290:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 291:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 292:
# Actual    : 0.38
# Predicted : 0.4
#
# Sample 293:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 294:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 295:
# Actual    : 0.43
# Predicted : 0.39
#
# Sample 296:
# Actual    : 0.45
# Predicted : 0.44
#
# Sample 297:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 298:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 299:
# Actual    : 0.45
# Predicted : 0.48
#
# Sample 300:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 301:
# Actual    : 0.4
# Predicted : 0.45
#
# Sample 302:
# Actual    : 0.45
# Predicted : 0.4
#
# Sample 303:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 304:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 305:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 306:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 307:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 308:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 309:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 310:
# Actual    : 0.5
# Predicted : 0.47
#
# Sample 311:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 312:
# Actual    : 0.48
# Predicted : 0.5
#
# Sample 313:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 314:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 315:
# Actual    : 0.4
# Predicted : 0.48
#
# Sample 316:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 317:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 318:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 319:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 320:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 321:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 322:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 323:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 324:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 325:
# Actual    : 0.4
# Predicted : 0.43
#
# Sample 326:
# Actual    : 0.45
# Predicted : 0.4
#
# Sample 327:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 328:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 329:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 330:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 331:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 332:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 333:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 334:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 335:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 336:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 337:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 338:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 339:
# Actual    : 0.45
# Predicted : 0.5
#
# Sample 340:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 341:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 342:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 343:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 344:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 345:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 346:
# Actual    : 0.45
# Predicted : 0.44
#
# Sample 347:
# Actual    : 0.48
# Predicted : 0.46
#
# Sample 348:
# Actual    : 0.52
# Predicted : 0.48
#
# Sample 349:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 350:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 351:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 352:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 353:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 354:
# Actual    : 0.52
# Predicted : 0.49
#
# Sample 355:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 356:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 357:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 358:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 359:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 360:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 361:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 362:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 363:
# Actual    : 0.55
# Predicted : 0.5
#
# Sample 364:
# Actual    : 0.6
# Predicted : 0.55
#
# Sample 365:
# Actual    : 0.6
# Predicted : 0.61
#
# Sample 366:
# Actual    : 0.6
# Predicted : 0.6
#
# Sample 367:
# Actual    : 0.55
# Predicted : 0.59
#
# Sample 368:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 369:
# Actual    : 0.38
# Predicted : 0.51
#
# Sample 370:
# Actual    : 0.38
# Predicted : 0.36
#
# Sample 371:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 372:
# Actual    : 0.36
# Predicted : 0.39
#
# Sample 373:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 374:
# Actual    : 0.33
# Predicted : 0.37
#
# Sample 375:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 376:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 377:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 378:
# Actual    : 0.38
# Predicted : 0.37
#
# Sample 379:
# Actual    : 0.38
# Predicted : 0.4
#
# Sample 380:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 381:
# Actual    : 0.4
# Predicted : 0.38
#
# Sample 382:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 383:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 384:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 385:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 386:
# Actual    : 0.43
# Predicted : 0.46
#
# Sample 387:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 388:
# Actual    : 0.4
# Predicted : 0.43
#
# Sample 389:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 390:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 391:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 392:
# Actual    : 0.38
# Predicted : 0.41
#
# Sample 393:
# Actual    : 0.43
# Predicted : 0.38
#
# Sample 394:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 395:
# Actual    : 0.45
# Predicted : 0.44
#
# Sample 396:
# Actual    : 0.48
# Predicted : 0.46
#
# Sample 397:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 398:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 399:
# Actual    : 0.45
# Predicted : 0.47
#
# Sample 400:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 401:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 402:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 403:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 404:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 405:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 406:
# Actual    : 0.45
# Predicted : 0.44
#
# Sample 407:
# Actual    : 0.5
# Predicted : 0.46
#
# Sample 408:
# Actual    : 0.45
# Predicted : 0.51
#
# Sample 409:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 410:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 411:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 412:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 413:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 414:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 415:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 416:
# Actual    : 0.4
# Predicted : 0.43
#
# Sample 417:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 418:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 419:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 420:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 421:
# Actual    : 0.38
# Predicted : 0.41
#
# Sample 422:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 423:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 424:
# Actual    : 0.4
# Predicted : 0.39
#
# Sample 425:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 426:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 427:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 428:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 429:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 430:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 431:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 432:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 433:
# Actual    : 0.5
# Predicted : 0.45
#
# Sample 434:
# Actual    : 0.5
# Predicted : 0.51
#
# Sample 435:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 436:
# Actual    : 0.4
# Predicted : 0.5
#
# Sample 437:
# Actual    : 0.4
# Predicted : 0.39
#
# Sample 438:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 439:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 440:
# Actual    : 0.45
# Predicted : 0.41
#
# Sample 441:
# Actual    : 0.45
# Predicted : 0.47
#
# Sample 442:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 443:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 444:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 445:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 446:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 447:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 448:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 449:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 450:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 451:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 452:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 453:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 454:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 455:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 456:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 457:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 458:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 459:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 460:
# Actual    : 0.62
# Predicted : 0.52
#
# Sample 461:
# Actual    : 0.62
# Predicted : 0.63
#
# Sample 462:
# Actual    : 0.62
# Predicted : 0.63
#
# Sample 463:
# Actual    : 0.52
# Predicted : 0.62
#
# Sample 464:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 465:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 466:
# Actual    : 0.45
# Predicted : 0.49
#
# Sample 467:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 468:
# Actual    : 0.36
# Predicted : 0.42
#
# Sample 469:
# Actual    : 0.31
# Predicted : 0.35
#
# Sample 470:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 471:
# Actual    : 0.29
# Predicted : 0.32
#
# Sample 472:
# Actual    : 0.29
# Predicted : 0.3
#
# Sample 473:
# Actual    : 0.29
# Predicted : 0.3
#
# Sample 474:
# Actual    : 0.29
# Predicted : 0.3
#
# Sample 475:
# Actual    : 0.33
# Predicted : 0.3
#
# Sample 476:
# Actual    : 0.33
# Predicted : 0.35
#
# Sample 477:
# Actual    : 0.36
# Predicted : 0.35
#
# Sample 478:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 479:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 480:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 481:
# Actual    : 0.38
# Predicted : 0.36
#
# Sample 482:
# Actual    : 0.4
# Predicted : 0.39
#
# Sample 483:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 484:
# Actual    : 0.45
# Predicted : 0.41
#
# Sample 485:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 486:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 487:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 488:
# Actual    : 0.45
# Predicted : 0.42
#
# Sample 489:
# Actual    : 0.43
# Predicted : 0.46
#
# Sample 490:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 491:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 492:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 493:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 494:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 495:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 496:
# Actual    : 0.55
# Predicted : 0.47
#
# Sample 497:
# Actual    : 0.55
# Predicted : 0.56
#
# Sample 498:
# Actual    : 0.48
# Predicted : 0.55
#
# Sample 499:
# Actual    : 0.55
# Predicted : 0.46
#
# Sample 500:
# Actual    : 0.55
# Predicted : 0.55
#
# Sample 501:
# Actual    : 0.52
# Predicted : 0.55
#
# Sample 502:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 503:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 504:
# Actual    : 0.48
# Predicted : 0.52
#
# Sample 505:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 506:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 507:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 508:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 509:
# Actual    : 0.43
# Predicted : 0.48
#
# Sample 510:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 511:
# Actual    : 0.4
# Predicted : 0.43
#
# Sample 512:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 513:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 514:
# Actual    : 0.38
# Predicted : 0.41
#
# Sample 515:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 516:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 517:
# Actual    : 0.36
# Predicted : 0.39
#
# Sample 518:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 519:
# Actual    : 0.38
# Predicted : 0.36
#
# Sample 520:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 521:
# Actual    : 0.4
# Predicted : 0.39
#
# Sample 522:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 523:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 524:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 525:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 526:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 527:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 528:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 529:
# Actual    : 0.45
# Predicted : 0.41
#
# Sample 530:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 531:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 532:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 533:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 534:
# Actual    : 0.38
# Predicted : 0.4
#
# Sample 535:
# Actual    : 0.4
# Predicted : 0.38
#
# Sample 536:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 537:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 538:
# Actual    : 0.45
# Predicted : 0.41
#
# Sample 539:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 540:
# Actual    : 0.5
# Predicted : 0.46
#
# Sample 541:
# Actual    : 0.5
# Predicted : 0.51
#
# Sample 542:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 543:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 544:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 545:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 546:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 547:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 548:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 549:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 550:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 551:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 552:
# Actual    : 0.48
# Predicted : 0.49
#
# Sample 553:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 554:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 555:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 556:
# Actual    : 0.55
# Predicted : 0.5
#
# Sample 557:
# Actual    : 0.55
# Predicted : 0.56
#
# Sample 558:
# Actual    : 0.55
# Predicted : 0.55
#
# Sample 559:
# Actual    : 0.48
# Predicted : 0.54
#
# Sample 560:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 561:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 562:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 563:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 564:
# Actual    : 0.31
# Predicted : 0.43
#
# Sample 565:
# Actual    : 0.31
# Predicted : 0.3
#
# Sample 566:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 567:
# Actual    : 0.29
# Predicted : 0.32
#
# Sample 568:
# Actual    : 0.29
# Predicted : 0.3
#
# Sample 569:
# Actual    : 0.29
# Predicted : 0.3
#
# Sample 570:
# Actual    : 0.33
# Predicted : 0.3
#
# Sample 571:
# Actual    : 0.33
# Predicted : 0.35
#
# Sample 572:
# Actual    : 0.33
# Predicted : 0.35
#
# Sample 573:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 574:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 575:
# Actual    : 0.38
# Predicted : 0.36
#
# Sample 576:
# Actual    : 0.43
# Predicted : 0.39
#
# Sample 577:
# Actual    : 0.4
# Predicted : 0.44
#
# Sample 578:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 579:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 580:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 581:
# Actual    : 0.38
# Predicted : 0.41
#
# Sample 582:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 583:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 584:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 585:
# Actual    : 0.45
# Predicted : 0.39
#
# Sample 586:
# Actual    : 0.45
# Predicted : 0.47
#
# Sample 587:
# Actual    : 0.48
# Predicted : 0.46
#
# Sample 588:
# Actual    : 0.45
# Predicted : 0.48
#
# Sample 589:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 590:
# Actual    : 0.45
# Predicted : 0.47
#
# Sample 591:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 592:
# Actual    : 0.45
# Predicted : 0.48
#
# Sample 593:
# Actual    : 0.52
# Predicted : 0.45
#
# Sample 594:
# Actual    : 0.5
# Predicted : 0.53
#
# Sample 595:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 596:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 597:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 598:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 599:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 600:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 601:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 602:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 603:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 604:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 605:
# Actual    : 0.48
# Predicted : 0.49
#
# Sample 606:
# Actual    : 0.45
# Predicted : 0.47
#
# Sample 607:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 608:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 609:
# Actual    : 0.4
# Predicted : 0.43
#
# Sample 610:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 611:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 612:
# Actual    : 0.38
# Predicted : 0.41
#
# Sample 613:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 614:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 615:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 616:
# Actual    : 0.4
# Predicted : 0.39
#
# Sample 617:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 618:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 619:
# Actual    : 0.45
# Predicted : 0.41
#
# Sample 620:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 621:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 622:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 623:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 624:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 625:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 626:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 627:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 628:
# Actual    : 0.45
# Predicted : 0.48
#
# Sample 629:
# Actual    : 0.4
# Predicted : 0.45
#
# Sample 630:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 631:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 632:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 633:
# Actual    : 0.45
# Predicted : 0.41
#
# Sample 634:
# Actual    : 0.45
# Predicted : 0.47
#
# Sample 635:
# Actual    : 0.5
# Predicted : 0.46
#
# Sample 636:
# Actual    : 0.52
# Predicted : 0.51
#
# Sample 637:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 638:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 639:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 640:
# Actual    : 0.52
# Predicted : 0.49
#
# Sample 641:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 642:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 643:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 644:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 645:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 646:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 647:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 648:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 649:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 650:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 651:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 652:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 653:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 654:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 655:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 656:
# Actual    : 0.45
# Predicted : 0.49
#
# Sample 657:
# Actual    : 0.38
# Predicted : 0.44
#
# Sample 658:
# Actual    : 0.38
# Predicted : 0.37
#
# Sample 659:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 660:
# Actual    : 0.36
# Predicted : 0.39
#
# Sample 661:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 662:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 663:
# Actual    : 0.33
# Predicted : 0.37
#
# Sample 664:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 665:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 666:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 667:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 668:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 669:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 670:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 671:
# Actual    : 0.38
# Predicted : 0.36
#
# Sample 672:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 673:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 674:
# Actual    : 0.4
# Predicted : 0.38
#
# Sample 675:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 676:
# Actual    : 0.38
# Predicted : 0.41
#
# Sample 677:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 678:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 679:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 680:
# Actual    : 0.4
# Predicted : 0.39
#
# Sample 681:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 682:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 683:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 684:
# Actual    : 0.45
# Predicted : 0.41
#
# Sample 685:
# Actual    : 0.48
# Predicted : 0.46
#
# Sample 686:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 687:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 688:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 689:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 690:
# Actual    : 0.45
# Predicted : 0.47
#
# Sample 691:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 692:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 693:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 694:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 695:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 696:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 697:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 698:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 699:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 700:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 701:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 702:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 703:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 704:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 705:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 706:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 707:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 708:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 709:
# Actual    : 0.43
# Predicted : 0.46
#
# Sample 710:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 711:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 712:
# Actual    : 0.43
# Predicted : 0.46
#
# Sample 713:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 714:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 715:
# Actual    : 0.43
# Predicted : 0.46
#
# Sample 716:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 717:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 718:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 719:
# Actual    : 0.5
# Predicted : 0.46
#
# Sample 720:
# Actual    : 0.52
# Predicted : 0.51
#
# Sample 721:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 722:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 723:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 724:
# Actual    : 0.4
# Predicted : 0.52
#
# Sample 725:
# Actual    : 0.4
# Predicted : 0.39
#
# Sample 726:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 727:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 728:
# Actual    : 0.45
# Predicted : 0.42
#
# Sample 729:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 730:
# Actual    : 0.45
# Predicted : 0.49
#
# Sample 731:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 732:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 733:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 734:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 735:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 736:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 737:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 738:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 739:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 740:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 741:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 742:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 743:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 744:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 745:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 746:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 747:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 748:
# Actual    : 0.62
# Predicted : 0.5
#
# Sample 749:
# Actual    : 0.62
# Predicted : 0.64
#
# Sample 750:
# Actual    : 0.62
# Predicted : 0.63
#
# Sample 751:
# Actual    : 0.55
# Predicted : 0.62
#
# Sample 752:
# Actual    : 0.55
# Predicted : 0.53
#
# Sample 753:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 754:
# Actual    : 0.52
# Predicted : 0.51
#
# Sample 755:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 756:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 757:
# Actual    : 0.4
# Predicted : 0.49
#
# Sample 758:
# Actual    : 0.4
# Predicted : 0.39
#
# Sample 759:
# Actual    : 0.36
# Predicted : 0.4
#
# Sample 760:
# Actual    : 0.33
# Predicted : 0.36
#
# Sample 761:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 762:
# Actual    : 0.33
# Predicted : 0.35
#
# Sample 763:
# Actual    : 0.33
# Predicted : 0.35
#
# Sample 764:
# Actual    : 0.33
# Predicted : 0.35
#
# Sample 765:
# Actual    : 0.33
# Predicted : 0.35
#
# Sample 766:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 767:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 768:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 769:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 770:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 771:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 772:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 773:
# Actual    : 0.33
# Predicted : 0.36
#
# Sample 774:
# Actual    : 0.33
# Predicted : 0.33
#
# Sample 775:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 776:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 777:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 778:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 779:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 780:
# Actual    : 0.33
# Predicted : 0.36
#
# Sample 781:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 782:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 783:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 784:
# Actual    : 0.38
# Predicted : 0.37
#
# Sample 785:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 786:
# Actual    : 0.4
# Predicted : 0.39
#
# Sample 787:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 788:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 789:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 790:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 791:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 792:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 793:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 794:
# Actual    : 0.52
# Predicted : 0.45
#
# Sample 795:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 796:
# Actual    : 0.5
# Predicted : 0.53
#
# Sample 797:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 798:
# Actual    : 0.45
# Predicted : 0.49
#
# Sample 799:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 800:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 801:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 802:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 803:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 804:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 805:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 806:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 807:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 808:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 809:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 810:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 811:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 812:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 813:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 814:
# Actual    : 0.55
# Predicted : 0.52
#
# Sample 815:
# Actual    : 0.52
# Predicted : 0.55
#
# Sample 816:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 817:
# Actual    : 0.55
# Predicted : 0.52
#
# Sample 818:
# Actual    : 0.52
# Predicted : 0.55
#
# Sample 819:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 820:
# Actual    : 0.43
# Predicted : 0.49
#
# Sample 821:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 822:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 823:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 824:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 825:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 826:
# Actual    : 0.48
# Predicted : 0.46
#
# Sample 827:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 828:
# Actual    : 0.45
# Predicted : 0.5
#
# Sample 829:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 830:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 831:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 832:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 833:
# Actual    : 0.52
# Predicted : 0.48
#
# Sample 834:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 835:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 836:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 837:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 838:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 839:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 840:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 841:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 842:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 843:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 844:
# Actual    : 0.64
# Predicted : 0.52
#
# Sample 845:
# Actual    : 0.64
# Predicted : 0.66
#
# Sample 846:
# Actual    : 0.64
# Predicted : 0.65
#
# Sample 847:
# Actual    : 0.62
# Predicted : 0.64
#
# Sample 848:
# Actual    : 0.6
# Predicted : 0.61
#
# Sample 849:
# Actual    : 0.6
# Predicted : 0.59
#
# Sample 850:
# Actual    : 0.52
# Predicted : 0.59
#
# Sample 851:
# Actual    : 0.52
# Predicted : 0.51
#
# Sample 852:
# Actual    : 0.52
# Predicted : 0.51
#
# Sample 853:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 854:
# Actual    : 0.48
# Predicted : 0.49
#
# Sample 855:
# Actual    : 0.45
# Predicted : 0.47
#
# Sample 856:
# Actual    : 0.4
# Predicted : 0.44
#
# Sample 857:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 858:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 859:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 860:
# Actual    : 0.33
# Predicted : 0.41
#
# Sample 861:
# Actual    : 0.33
# Predicted : 0.33
#
# Sample 862:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 863:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 864:
# Actual    : 0.31
# Predicted : 0.35
#
# Sample 865:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 866:
# Actual    : 0.29
# Predicted : 0.32
#
# Sample 867:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 868:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 869:
# Actual    : 0.29
# Predicted : 0.3
#
# Sample 870:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 871:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 872:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 873:
# Actual    : 0.31
# Predicted : 0.29
#
# Sample 874:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 875:
# Actual    : 0.33
# Predicted : 0.32
#
# Sample 876:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 877:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 878:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 879:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 880:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 881:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 882:
# Actual    : 0.4
# Predicted : 0.36
#
# Sample 883:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 884:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 885:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 886:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 887:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 888:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 889:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 890:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 891:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 892:
# Actual    : 0.4
# Predicted : 0.45
#
# Sample 893:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 894:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 895:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 896:
# Actual    : 0.45
# Predicted : 0.41
#
# Sample 897:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 898:
# Actual    : 0.48
# Predicted : 0.49
#
# Sample 899:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 900:
# Actual    : 0.45
# Predicted : 0.47
#
# Sample 901:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 902:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 903:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 904:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 905:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 906:
# Actual    : 0.48
# Predicted : 0.5
#
# Sample 907:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 908:
# Actual    : 0.48
# Predicted : 0.47
#
# Sample 909:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 910:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 911:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 912:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 913:
# Actual    : 0.52
# Predicted : 0.53
#
# Sample 914:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 915:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 916:
# Actual    : 0.45
# Predicted : 0.52
#
# Sample 917:
# Actual    : 0.45
# Predicted : 0.44
#
# Sample 918:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 919:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 920:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 921:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 922:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 923:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 924:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 925:
# Actual    : 0.5
# Predicted : 0.47
#
# Sample 926:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 927:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 928:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 929:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 930:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 931:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 932:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 933:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 934:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 935:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 936:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 937:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 938:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 939:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 940:
# Actual    : 0.67
# Predicted : 0.5
#
# Sample 941:
# Actual    : 0.67
# Predicted : 0.69
#
# Sample 942:
# Actual    : 0.67
# Predicted : 0.68
#
# Sample 943:
# Actual    : 0.52
# Predicted : 0.67
#
# Sample 944:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 945:
# Actual    : 0.45
# Predicted : 0.48
#
# Sample 946:
# Actual    : 0.45
# Predicted : 0.44
#
# Sample 947:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 948:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 949:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 950:
# Actual    : 0.4
# Predicted : 0.43
#
# Sample 951:
# Actual    : 0.38
# Predicted : 0.4
#
# Sample 952:
# Actual    : 0.36
# Predicted : 0.38
#
# Sample 953:
# Actual    : 0.38
# Predicted : 0.36
#
# Sample 954:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 955:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 956:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 957:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 958:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 959:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 960:
# Actual    : 0.4
# Predicted : 0.39
#
# Sample 961:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 962:
# Actual    : 0.38
# Predicted : 0.41
#
# Sample 963:
# Actual    : 0.4
# Predicted : 0.38
#
# Sample 964:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 965:
# Actual    : 0.38
# Predicted : 0.41
#
# Sample 966:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 967:
# Actual    : 0.4
# Predicted : 0.38
#
# Sample 968:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 969:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 970:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 971:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 972:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 973:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 974:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 975:
# Actual    : 0.4
# Predicted : 0.44
#
# Sample 976:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 977:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 978:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 979:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 980:
# Actual    : 0.48
# Predicted : 0.48
#
# Sample 981:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 982:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 983:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 984:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 985:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 986:
# Actual    : 0.52
# Predicted : 0.5
#
# Sample 987:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 988:
# Actual    : 0.52
# Predicted : 0.52
#
# Sample 989:
# Actual    : 0.5
# Predicted : 0.52
#
# Sample 990:
# Actual    : 0.5
# Predicted : 0.49
#
# Sample 991:
# Actual    : 0.48
# Predicted : 0.49
#
# Sample 992:
# Actual    : 0.4
# Predicted : 0.47
#
# Sample 993:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 994:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 995:
# Actual    : 0.38
# Predicted : 0.41
#
# Sample 996:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 997:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 998:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 999:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 1000:
# Actual    : 0.45
# Predicted : 0.39
#
# Sample 1001:
# Actual    : 0.45
# Predicted : 0.47
#
# Sample 1002:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 1003:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 1004:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 1005:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 1006:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 1007:
# Actual    : 0.43
# Predicted : 0.43
#
# Sample 1008:
# Actual    : 0.45
# Predicted : 0.43
#
# Sample 1009:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 1010:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 1011:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 1012:
# Actual    : 0.4
# Predicted : 0.45
#
# Sample 1013:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 1014:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 1015:
# Actual    : 0.43
# Predicted : 0.41
#
# Sample 1016:
# Actual    : 0.43
# Predicted : 0.44
#
# Sample 1017:
# Actual    : 0.45
# Predicted : 0.44
#
# Sample 1018:
# Actual    : 0.45
# Predicted : 0.46
#
# Sample 1019:
# Actual    : 0.48
# Predicted : 0.45
#
# Sample 1020:
# Actual    : 0.5
# Predicted : 0.48
#
# Sample 1021:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 1022:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 1023:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 1024:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 1025:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 1026:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 1027:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 1028:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 1029:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 1030:
# Actual    : 0.5
# Predicted : 0.5
#
# Sample 1031:
# Actual    : 0.5
# ...
# Predicted : 0.36
#
# Sample 30167:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30168:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30169:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30170:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30171:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30172:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30173:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30174:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30175:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30176:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30177:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30178:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30179:
# Actual    : 0.33
# Predicted : 0.36
#
# Sample 30180:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30181:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30182:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30183:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30184:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30185:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30186:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30187:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30188:
# Actual    : 0.29
# Predicted : 0.34
#
# Sample 30189:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30190:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30191:
# Actual    : 0.33
# Predicted : 0.29
#
# Sample 30192:
# Actual    : 0.36
# Predicted : 0.35
#
# Sample 30193:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 30194:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30195:
# Actual    : 0.33
# Predicted : 0.36
#
# Sample 30196:
# Actual    : 0.29
# Predicted : 0.33
#
# Sample 30197:
# Actual    : 0.24
# Predicted : 0.28
#
# Sample 30198:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30199:
# Actual    : 0.26
# Predicted : 0.24
#
# Sample 30200:
# Actual    : 0.29
# Predicted : 0.27
#
# Sample 30201:
# Actual    : 0.29
# Predicted : 0.3
#
# Sample 30202:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30203:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30204:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30205:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30206:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30207:
# Actual    : 0.31
# Predicted : 0.29
#
# Sample 30208:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30209:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30210:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30211:
# Actual    : 0.33
# Predicted : 0.31
#
# Sample 30212:
# Actual    : 0.31
# Predicted : 0.34
#
# Sample 30213:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30214:
# Actual    : 0.33
# Predicted : 0.31
#
# Sample 30215:
# Actual    : 0.31
# Predicted : 0.34
#
# Sample 30216:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30217:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30218:
# Actual    : 0.33
# Predicted : 0.31
#
# Sample 30219:
# Actual    : 0.43
# Predicted : 0.34
#
# Sample 30220:
# Actual    : 0.43
# Predicted : 0.46
#
# Sample 30221:
# Actual    : 0.4
# Predicted : 0.44
#
# Sample 30222:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 30223:
# Actual    : 0.38
# Predicted : 0.4
#
# Sample 30224:
# Actual    : 0.33
# Predicted : 0.38
#
# Sample 30225:
# Actual    : 0.31
# Predicted : 0.33
#
# Sample 30226:
# Actual    : 0.29
# Predicted : 0.31
#
# Sample 30227:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30228:
# Actual    : 0.29
# Predicted : 0.3
#
# Sample 30229:
# Actual    : 0.26
# Predicted : 0.3
#
# Sample 30230:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30231:
# Actual    : 0.24
# Predicted : 0.27
#
# Sample 30232:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30233:
# Actual    : 0.26
# Predicted : 0.24
#
# Sample 30234:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30235:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30236:
# Actual    : 0.29
# Predicted : 0.27
#
# Sample 30237:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30238:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30239:
# Actual    : 0.31
# Predicted : 0.29
#
# Sample 30240:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30241:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30242:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30243:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30244:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30245:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30246:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30247:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30248:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30249:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30250:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30251:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30252:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30253:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30254:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30255:
# Actual    : 0.36
# Predicted : 0.31
#
# Sample 30256:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 30257:
# Actual    : 0.4
# Predicted : 0.37
#
# Sample 30258:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 30259:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 30260:
# Actual    : 0.4
# Predicted : 0.41
#
# Sample 30261:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 30262:
# Actual    : 0.38
# Predicted : 0.41
#
# Sample 30263:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 30264:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 30265:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 30266:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 30267:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 30268:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 30269:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 30270:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 30271:
# Actual    : 0.36
# Predicted : 0.39
#
# Sample 30272:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30273:
# Actual    : 0.33
# Predicted : 0.36
#
# Sample 30274:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30275:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30276:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30277:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30278:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30279:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30280:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30281:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30282:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30283:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30284:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30285:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30286:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30287:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30288:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 30289:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 30290:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30291:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30292:
# Actual    : 0.26
# Predicted : 0.36
#
# Sample 30293:
# Actual    : 0.26
# Predicted : 0.26
#
# Sample 30294:
# Actual    : 0.26
# Predicted : 0.26
#
# Sample 30295:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30296:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30297:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30298:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30299:
# Actual    : 0.29
# Predicted : 0.27
#
# Sample 30300:
# Actual    : 0.31
# Predicted : 0.29
#
# Sample 30301:
# Actual    : 0.33
# Predicted : 0.32
#
# Sample 30302:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30303:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30304:
# Actual    : 0.33
# Predicted : 0.33
#
# Sample 30305:
# Actual    : 0.33
# Predicted : 0.33
#
# Sample 30306:
# Actual    : 0.31
# Predicted : 0.34
#
# Sample 30307:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30308:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30309:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30310:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 30311:
# Actual    : 0.33
# Predicted : 0.32
#
# Sample 30312:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30313:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30314:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30315:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30316:
# Actual    : 0.4
# Predicted : 0.34
#
# Sample 30317:
# Actual    : 0.43
# Predicted : 0.42
#
# Sample 30318:
# Actual    : 0.45
# Predicted : 0.44
#
# Sample 30319:
# Actual    : 0.43
# Predicted : 0.46
#
# Sample 30320:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 30321:
# Actual    : 0.38
# Predicted : 0.4
#
# Sample 30322:
# Actual    : 0.38
# Predicted : 0.37
#
# Sample 30323:
# Actual    : 0.33
# Predicted : 0.38
#
# Sample 30324:
# Actual    : 0.29
# Predicted : 0.33
#
# Sample 30325:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30326:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30327:
# Actual    : 0.26
# Predicted : 0.3
#
# Sample 30328:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30329:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30330:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30331:
# Actual    : 0.24
# Predicted : 0.27
#
# Sample 30332:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30333:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30334:
# Actual    : 0.26
# Predicted : 0.24
#
# Sample 30335:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30336:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30337:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30338:
# Actual    : 0.24
# Predicted : 0.27
#
# Sample 30339:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30340:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30341:
# Actual    : 0.24
# Predicted : 0.25
#
# Sample 30342:
# Actual    : 0.26
# Predicted : 0.25
#
# Sample 30343:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30344:
# Actual    : 0.29
# Predicted : 0.27
#
# Sample 30345:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30346:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30347:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30348:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30349:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30350:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30351:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30352:
# Actual    : 0.31
# Predicted : 0.29
#
# Sample 30353:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30354:
# Actual    : 0.33
# Predicted : 0.31
#
# Sample 30355:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30356:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30357:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30358:
# Actual    : 0.31
# Predicted : 0.34
#
# Sample 30359:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30360:
# Actual    : 0.36
# Predicted : 0.31
#
# Sample 30361:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 30362:
# Actual    : 0.31
# Predicted : 0.37
#
# Sample 30363:
# Actual    : 0.36
# Predicted : 0.31
#
# Sample 30364:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30365:
# Actual    : 0.33
# Predicted : 0.37
#
# Sample 30366:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30367:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30368:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30369:
# Actual    : 0.31
# Predicted : 0.34
#
# Sample 30370:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30371:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30372:
# Actual    : 0.29
# Predicted : 0.32
#
# Sample 30373:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30374:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30375:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30376:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30377:
# Actual    : 0.31
# Predicted : 0.29
#
# Sample 30378:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 30379:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 30380:
# Actual    : 0.33
# Predicted : 0.31
#
# Sample 30381:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30382:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30383:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30384:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 30385:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30386:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30387:
# Actual    : 0.33
# Predicted : 0.36
#
# Sample 30388:
# Actual    : 0.29
# Predicted : 0.33
#
# Sample 30389:
# Actual    : 0.26
# Predicted : 0.28
#
# Sample 30390:
# Actual    : 0.26
# Predicted : 0.26
#
# Sample 30391:
# Actual    : 0.24
# Predicted : 0.27
#
# Sample 30392:
# Actual    : 0.26
# Predicted : 0.24
#
# Sample 30393:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30394:
# Actual    : 0.29
# Predicted : 0.27
#
# Sample 30395:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30396:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30397:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30398:
# Actual    : 0.29
# Predicted : 0.29
#
# Sample 30399:
# Actual    : 0.31
# Predicted : 0.29
#
# Sample 30400:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30401:
# Actual    : 0.33
# Predicted : 0.31
#
# Sample 30402:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30403:
# Actual    : 0.31
# Predicted : 0.34
#
# Sample 30404:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30405:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30406:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30407:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30408:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30409:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30410:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30411:
# Actual    : 0.33
# Predicted : 0.31
#
# Sample 30412:
# Actual    : 0.45
# Predicted : 0.34
#
# Sample 30413:
# Actual    : 0.45
# Predicted : 0.48
#
# Sample 30414:
# Actual    : 0.45
# Predicted : 0.47
#
# Sample 30415:
# Actual    : 0.45
# Predicted : 0.45
#
# Sample 30416:
# Actual    : 0.43
# Predicted : 0.45
#
# Sample 30417:
# Actual    : 0.4
# Predicted : 0.42
#
# Sample 30418:
# Actual    : 0.4
# Predicted : 0.4
#
# Sample 30419:
# Actual    : 0.38
# Predicted : 0.4
#
# Sample 30420:
# Actual    : 0.38
# Predicted : 0.38
#
# Sample 30421:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 30422:
# Actual    : 0.36
# Predicted : 0.39
#
# Sample 30423:
# Actual    : 0.33
# Predicted : 0.36
#
# Sample 30424:
# Actual    : 0.29
# Predicted : 0.34
#
# Sample 30425:
# Actual    : 0.26
# Predicted : 0.29
#
# Sample 30426:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30427:
# Actual    : 0.24
# Predicted : 0.27
#
# Sample 30428:
# Actual    : 0.24
# Predicted : 0.25
#
# Sample 30429:
# Actual    : 0.24
# Predicted : 0.25
#
# Sample 30430:
# Actual    : 0.24
# Predicted : 0.25
#
# Sample 30431:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30432:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30433:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30434:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30435:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30436:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30437:
# Actual    : 0.24
# Predicted : 0.25
#
# Sample 30438:
# Actual    : 0.24
# Predicted : 0.25
#
# Sample 30439:
# Actual    : 0.24
# Predicted : 0.25
#
# Sample 30440:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30441:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30442:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30443:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30444:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30445:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30446:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30447:
# Actual    : 0.24
# Predicted : 0.24
#
# Sample 30448:
# Actual    : 0.26
# Predicted : 0.24
#
# Sample 30449:
# Actual    : 0.26
# Predicted : 0.27
#
# Sample 30450:
# Actual    : 0.29
# Predicted : 0.27
#
# Sample 30451:
# Actual    : 0.31
# Predicted : 0.29
#
# Sample 30452:
# Actual    : 0.33
# Predicted : 0.31
#
# Sample 30453:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30454:
# Actual    : 0.31
# Predicted : 0.34
#
# Sample 30455:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30456:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30457:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30458:
# Actual    : 0.33
# Predicted : 0.31
#
# Sample 30459:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30460:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30461:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30462:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30463:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30464:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 30465:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 30466:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30467:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30468:
# Actual    : 0.31
# Predicted : 0.36
#
# Sample 30469:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30470:
# Actual    : 0.31
# Predicted : 0.31
#
# Sample 30471:
# Actual    : 0.33
# Predicted : 0.32
#
# Sample 30472:
# Actual    : 0.33
# Predicted : 0.35
#
# Sample 30473:
# Actual    : 0.33
# Predicted : 0.34
#
# Sample 30474:
# Actual    : 0.36
# Predicted : 0.34
#
# Sample 30475:
# Actual    : 0.36
# Predicted : 0.37
#
# Sample 30476:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30477:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30478:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30479:
# Actual    : 0.38
# Predicted : 0.36
#
# Sample 30480:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 30481:
# Actual    : 0.38
# Predicted : 0.39
#
# Sample 30482:
# Actual    : 0.36
# Predicted : 0.38
#
# Sample 30483:
# Actual    : 0.36
# Predicted : 0.36
#
# Sample 30484:
# Actual    : 0.29
# Predicted : 0.36
#
# Sample 30485:
# Actual    : 0.26
# Predicted : 0.28
#
# Sample 30486:
# Actual    : 0.26
# Predicted : 0.26
#
# Sample 30487:
# Actual    : 0.29
# Predicted : 0.27
#
# Sample 30488:
# Actual    : 0.29
# Predicted : 0.3
#
# Sample 30489:
# Actual    : 0.31
# Predicted : 0.3
#
# Sample 30490:
# Actual    : 0.31
# Predicted : 0.32
#
# Sample 30491:
# Actual    : 0.31
# Predicted : 0.32
#
# --- Evaluation Metrics ---
# MAE: 0.0133
# RMSE: 0.0217
# MAPE: 2.90%

# %%
import matplotlib.pyplot as plt
import numpy as np

# Actual and predicted values from your message
actual = np.array([
    0.40, 0.40, 0.40, 0.40, 0.40, 0.38, 0.38, 0.40, 0.40, 0.43,
    0.43, 0.43, 0.43, 0.48, 0.48, 0.45, 0.45, 0.45, 0.45, 0.48,
    0.48, 0.50, 0.50, 0.50, 0.48, 0.48, 0.48, 0.48, 0.45, 0.43
])
predicted = np.array([
    0.34, 0.42, 0.42, 0.41, 0.40, 0.40, 0.38, 0.38, 0.41, 0.41,
    0.44, 0.43, 0.43, 0.43, 0.48, 0.48, 0.45, 0.45, 0.45, 0.45,
    0.48, 0.48, 0.50, 0.50, 0.50, 0.47, 0.47, 0.48, 0.48, 0.45
])

# Calculate differences
differences = np.round(actual - predicted, 3)

# Plot
plt.figure(figsize=(14, 6))
bars = plt.bar(np.arange(1, len(differences) + 1), differences, color='skyblue', edgecolor='black')

# Annotate each bar with the value
for i, diff in enumerate(differences):
    plt.text(i + 1, diff + 0.002 if diff >= 0 else diff - 0.005, f"{diff:.2f}",
             ha='center', va='bottom' if diff >= 0 else 'top', fontsize=8)

plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.title("Difference per Sample (Actual - Predicted)", fontsize=16)
plt.xlabel("Sample Number", fontsize=12)
plt.ylabel("Difference", fontsize=12)
plt.xticks(np.arange(1, len(differences) + 1))
plt.tight_layout()
plt.grid(axis='y', linestyle=':', linewidth=0.5, alpha=0.7)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Extract the first 30 samples
actual_30 = y_test[:30].flatten()
predicted_30 = y_pred[:30].flatten()
samples = np.arange(1, 31)

# Calculate differences
differences = np.round(actual_30 - predicted_30, 3)

# Create the figure
plt.figure(figsize=(10, 8))

# Plot actual and predicted values
plt.plot(samples, actual_30, marker='o', label='Actual', color='blue')
plt.plot(samples, predicted_30, marker='o', label='Predicted', color='red', linestyle='--')

# Highlight the differences with vertical lines
for i in range(len(samples)):
    plt.vlines(x=samples[i], ymin=min(actual_30[i], predicted_30[i]), ymax=max(actual_30[i], predicted_30[i]),
               color='black', linestyle=':', alpha=0.6)

# Annotate differences above each line
for i, diff in enumerate(differences):
    plt.text(samples[i], max(actual_30[i], predicted_30[i]) + 0.005, f"{diff:+.2f}", 
             ha='center', fontsize=8, color='black')

# Labels and layout
plt.title("Actual vs Predicted Values (First 30 Samples)", fontsize=16)
plt.xlabel("Sample Index", fontsize=12)
plt.ylabel("Value", fontsize=12)
plt.legend(fontsize=10)
plt.grid(True, linestyle=':', alpha=0.5)
plt.tight_layout()
plt.show()
